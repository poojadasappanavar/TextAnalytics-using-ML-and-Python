# %%
import pandas as pd
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Requirements Dataset.csv")

# %%
df
# Out:
#                                                 Topic  \
# 0                              House Price Prediction
# 1                Anomaly Detection In Ship Trajectory
# 2                     Hand written digits recognition
# 3                                  Social Network Ads
# 4                music classification based on lyrics
# 5                             Stock Market Prediction
# 6           Optical recognition of handwritten digits
# 7                            Diabetes Risk Prediction
# 8                    Stock Price prediction using Knn
# 9               NLP -BASED ARTIFICIAL INTELLIGENT BOT
# 10            NLP- Based Artificially Intelligent Bot
# 11                               Precting stock price
# 12                             Traffic Sign Detection
# 13                             Predicting House Price
# 14                          Number Plate Verification
# 15                     FACE DETECTION AND RECOGNITION
# ...

# %%
df.head(10)
# Out:
#                                        Topic  \
# 0                     House Price Prediction
# 1       Anomaly Detection In Ship Trajectory
# 2            Hand written digits recognition
# 3                         Social Network Ads
# 4       music classification based on lyrics
# 5                    Stock Market Prediction
# 6  Optical recognition of handwritten digits
# 7                   Diabetes Risk Prediction
# 8           Stock Price prediction using Knn
# 9      NLP -BASED ARTIFICIAL INTELLIGENT BOT
#
#                              Functional Requirements  \
# 0  This application is based on machine learning\...
# 1  The algorithm should be able to predict the an...
# 2   Consistent performance for minute and bulk data.
# 3  K-nearest neighbour algorithm is used.\nDatase...
# 4  Hardware:\nIntel core processor i3\n4GB RAM\n\...
# 5  Hardware Requirements:\n Core i3 processor\nS...
# 6  Datasets :MNIST dataset which includes both fe...
# ...

# %%
df['Topic'].dtypes
# Out:
# dtype('O')

# %%
df['Topic'][5:30]
# Out:
# 5                               Stock Market Prediction
# 6             Optical recognition of handwritten digits
# 7                              Diabetes Risk Prediction
# 8                      Stock Price prediction using Knn
# 9                 NLP -BASED ARTIFICIAL INTELLIGENT BOT
# 10              NLP- Based Artificially Intelligent Bot
# 11                                 Precting stock price
# 12                               Traffic Sign Detection
# 13                               Predicting House Price
# 14                            Number Plate Verification
# 15                       FACE DETECTION AND RECOGNITION
# 16                                          Face Detect
# 17                                  Chatbot for College
# 18                                      Face Detection
# 19                   Opinion Mining of Customer Reviews
# 20                     Handwritten digit classification
# 21                   Sentiment Analysis of textual data
# ...

# %%
df[['Topic','Algorithms']][1:6]
# Out:
#                                   Topic           Algorithms
# 1  Anomaly Detection In Ship Trajectory          SVM and KNN
# 2       Hand written digits recognition                  KNN
# 3                    Social Network Ads  K-Nearest Neighbour
# 4  music classification based on lyrics          naive bayes
# 5               Stock Market Prediction       Neural Network

# %%
d=df['Programming Language used'].value_counts()

# %%
df['Tools used'].value_counts()
# Out:
# R studio                                         4
# R Studio                                         3
# MATLAB                                           2
# Matlab                                           2
# Python 2.7                                       2
# Anaconda                                         2
# R-tool                                           1
# Ipython                                          1
# python 5                                         1
# Android Studio                                   1
# Pycharm community 2018                           1
# Pycharm                                          1
# MATLAB \nWindows 10                              1
# idle                                             1
# OpenCV, numpy                                    1
# R and R Studio                                   1
# Anaconda, openCV, Python IDLE                    1
# octave                                           1
# ...

# %%
d[:10].plot(kind='bar')

# %%
objects=(df['Topic'][1:5])
y_pos = np.arange(len(objects))
performance = [] 
performance =df['Tools used'].value_counts()[1:5]

# %%
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Tools used')
plt.xlabel('Topics')
plt.title('Dataset')
 
plt.show()

# %%
import matplotlib.pyplot as plt
 
# Data to plot
labels = df['Tools used'][1:5]
sizes = df['Programming Language used'].value_counts()[1:5]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()

# %%
lst=df['Tools used'].value_counts()[5:10]
it=iter(lst)
x=np.fromiter(it,dtype=float)
print(x,      df['Topic'][5:10])
print(lst)
# Out:
# [2. 1. 1. 1. 1.] 5                      Stock Market Prediction
# 6    Optical recognition of handwritten digits
# 7                     Diabetes Risk Prediction
# 8             Stock Price prediction using Knn
# 9        NLP -BASED ARTIFICIAL INTELLIGENT BOT
# Name: Topic, dtype: object
# Anaconda          2
# R-tool            1
# Ipython           1
# python 5          1
# Android Studio    1
# Name: Tools used, dtype: int64
