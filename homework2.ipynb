# %%
import pandas as pd
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Deaths-by-statistical-area-2-and-area-unit-for-comparison.csv")

# %%
df
# Out:
#            geography type    code                 description  2013  2014  \
# 0      Statistical_Area_2  100100                  North Cape    24    15
# 1      Statistical_Area_3  100200            Rangaunu Harbour    24     9
# 2      Statistical_Area_4  100300   Inlets Far North District     0     0
# 3      Statistical_Area_5  100400          Karikari Peninsula     9     9
# 4      Statistical_Area_6  100500                    Tangonge     6     6
# 5      Statistical_Area_7  100600                     Ahipara     9    12
# 6      Statistical_Area_8  100700                Kaitaia East    27    15
# 7      Statistical_Area_9  100800                Kaitaia West    48    60
# 8     Statistical_Area_10  100900                   Rangitihi     3     6
# 9     Statistical_Area_11  101000              Oruru-Parapara     3     6
# 10    Statistical_Area_12  101100                 Taumarumaru    18    15
# 11    Statistical_Area_13  101200            Herekino-Takahue     3    12
# ...

# %%
df.shape
# Out:
# (4439, 8)

# %%
df.head(10)
# Out:
#         geography type    code                description  2013  2014  2015  \
# 0   Statistical_Area_2  100100                 North Cape    24    15    18
# 1   Statistical_Area_3  100200           Rangaunu Harbour    24     9    12
# 2   Statistical_Area_4  100300  Inlets Far North District     0     0     0
# 3   Statistical_Area_5  100400         Karikari Peninsula     9     9     9
# 4   Statistical_Area_6  100500                   Tangonge     6     6     6
# 5   Statistical_Area_7  100600                    Ahipara     9    12     6
# 6   Statistical_Area_8  100700               Kaitaia East    27    15    27
# 7   Statistical_Area_9  100800               Kaitaia West    48    60    69
# 8  Statistical_Area_10  100900                  Rangitihi     3     6     6
# 9  Statistical_Area_11  101000             Oruru-Parapara     3     6     3
#
#    2016  2017
# 0    18     6
# 1    12    15
# 2     0     0
# 3    18    15
# 4    12     3
# 5     9     6
# 6    21    18
# ...

# %%
df.tail(10)
# Out:
#       geography type    code                description  2013  2014  2015  \
# 4429  Area_Unit_2188  666666           NZ Economic Zone     0     0     0
# 4430  Area_Unit_2189  666667           NZ Economic Zone     0     0     0
# 4431  Area_Unit_2190  666668     Oceanic-Bounty Islands     0     0     0
# 4432  Area_Unit_2191  666669             Bounty Islands     0     0     0
# 4433  Area_Unit_2192  666670     Oceanic-Snares Islands     0     0     0
# 4434  Area_Unit_2193  666671              Snares Island     0     0     0
# 4435  Area_Unit_2194  666672  Oceanic-Antipodes Islands     0     0     0
# 4436  Area_Unit_2195  666673          Antipodes Islands     0     0     0
# 4437  Area_Unit_2196  999998  Not Specified New Zealand    21    33    18
# 4438  Area_Unit_2197  999999    Not Applicable Overseas     0     0     0
#
#       2016  2017
# 4429     0     0
# 4430     0     0
# 4431     0     0
# 4432     0     0
# 4433     0     0
# 4434     0     0
# 4435     0     0
# ...

# %%
df["code"].dtypes
# Out:
# dtype('int64')

# %%
print(df["code"].dtypes)
# Out:
# int64

# %%
df["geography type"][2:15]
# Out:
# 2      Statistical_Area_4
# 3      Statistical_Area_5
# 4      Statistical_Area_6
# 5      Statistical_Area_7
# 6      Statistical_Area_8
# 7      Statistical_Area_9
# 8     Statistical_Area_10
# 9     Statistical_Area_11
# 10    Statistical_Area_12
# 11    Statistical_Area_13
# 12    Statistical_Area_14
# 13    Statistical_Area_15
# 14    Statistical_Area_16
# Name: geography type, dtype: object

# %%
df["2016"][5:45]
# Out:
# 5      9
# 6     21
# 7     60
# 8      9
# 9      6
# 10     6
# 11     3
# 12     9
# 13     6
# 14     6
# 15    12
# 16     9
# 17     6
# 18    12
# 19     9
# 20    18
# 21     9
# 22     3
# 23     9
# 24     0
# 25     9
# 26     9
# 27    18
# 28     9
# 29    42
# 30    12
# 31     6
# 32     9
# 33    21
# 34    45
# 35     6
# 36    18
# 37    12
# 38    12
# 39     3
# 40    15
# 41     3
# 42     9
# 43     9
# 44    12
# Name: 2016, dtype: int64

# %%
df[3000:4000]
# Out:
#       geography type    code                      description  2013  2014  \
# 3000   Area_Unit_759  536201               Papamoa Beach East    12     9
# 3001   Area_Unit_760  536202                     Palm Springs    12    12
# 3002   Area_Unit_761  536203                        Doncaster    12    15
# 3003   Area_Unit_762  536400           Island View-Pios Beach     6     9
# 3004   Area_Unit_763  536503                          Te Puna    18     9
# 3005   Area_Unit_764  536505                         Matapihi     6     6
# 3006   Area_Unit_765  536506  Inlet-Tauranga Harbour Omokoroa     0     0
# 3007   Area_Unit_766  536508           Inlet-Tauranga Harbour     0     0
# 3008   Area_Unit_767  536509                Waikareao Estuary     0     0
# 3009   Area_Unit_768  536510                  Motuopae Island     0     0
# 3010   Area_Unit_769  536511               Papamoa Beach West     0     0
# 3011   Area_Unit_770  536512                           Kairua     0     0
# ...

# %%
df["code"][1:5]
# Out:
# 1    100200
# 2    100300
# 3    100400
# 4    100500
# Name: code, dtype: int64

# %%
df[['geography type','code','description','2016']][:10]
# Out:
#         geography type    code                description  2016
# 0   Statistical_Area_2  100100                 North Cape    18
# 1   Statistical_Area_3  100200           Rangaunu Harbour    12
# 2   Statistical_Area_4  100300  Inlets Far North District     0
# 3   Statistical_Area_5  100400         Karikari Peninsula    18
# 4   Statistical_Area_6  100500                   Tangonge    12
# 5   Statistical_Area_7  100600                    Ahipara     9
# 6   Statistical_Area_8  100700               Kaitaia East    21
# 7   Statistical_Area_9  100800               Kaitaia West    60
# 8  Statistical_Area_10  100900                  Rangitihi     9
# 9  Statistical_Area_11  101000             Oruru-Parapara     6

# %%
df['2016'].value_counts()
# Out:
# 0      785
# 3      563
# 6      548
# 9      522
# 12     417
# 15     300
# 18     288
# 21     185
# 24     129
# 27     110
# 30      82
# 36      69
# 33      66
# 39      52
# 45      47
# 42      43
# 51      35
# 48      34
# 60      27
# 54      20
# 66      18
# 72      14
# 63      14
# 57      14
# 75      13
# 69       8
# 84       7
# 90       4
# 87       4
# 111      3
# 81       3
# 102      3
# 108      2
# 96       2
# 78       2
# 192      1
# 141      1
# 99       1
# 114      1
# 126      1
# 105      1
# Name: 2016, dtype: int64

# %%
d=df['2013'].value_counts()
d[:20]
# Out:
# 0     803
# 3     642
# 6     547
# 9     474
# 12    422
# 15    313
# 18    260
# 21    173
# 24    138
# 27    115
# 30    103
# 36     64
# 33     56
# 39     50
# 42     41
# 51     32
# 48     31
# 54     30
# 45     28
# 57     17
# Name: 2013, dtype: int64

# %%
d[:20].plot(kind='bar')

# %%
d=df['geography type'].value_counts()
d[:20]
# Out:
# Statistical_Area_531     1
# Area_Unit_896            1
# Area_Unit_1639           1
# Statistical_Area_1162    1
# Area_Unit_1307           1
# Area_Unit_1825           1
# Statistical_Area_1601    1
# Area_Unit_212            1
# Statistical_Area_859     1
# Area_Unit_1090           1
# Area_Unit_224            1
# Statistical_Area_954     1
# Statistical_Area_1576    1
# Statistical_Area_696     1
# Area_Unit_1749           1
# Statistical_Area_635     1
# Statistical_Area_2075    1
# Statistical_Area_1932    1
# Statistical_Area_679     1
# Statistical_Area_2033    1
# Name: geography type, dtype: int64

# %%
d[:10].plot(kind='pie')

# %%
d[:10].plot(kind='bar')

# %%
d[:10].plot(kind='line')

# %%
d=df['code'].value_counts()
d[:10]
# Out:
# 999998    2
# 569400    1
# 607400    1
# 584304    1
# 614700    1
# 588402    1
# 182900    1
# 575901    1
# 191100    1
# 502400    1
# Name: code, dtype: int64

# %%
d[:10].plot(kind='bar')

# %%
d[:10].plot(kind='line')

# %%
df
# Out:
#            geography type    code                 description  2013  2014  \
# 0      Statistical_Area_2  100100                  North Cape    24    15
# 1      Statistical_Area_3  100200            Rangaunu Harbour    24     9
# 2      Statistical_Area_4  100300   Inlets Far North District     0     0
# 3      Statistical_Area_5  100400          Karikari Peninsula     9     9
# 4      Statistical_Area_6  100500                    Tangonge     6     6
# 5      Statistical_Area_7  100600                     Ahipara     9    12
# 6      Statistical_Area_8  100700                Kaitaia East    27    15
# 7      Statistical_Area_9  100800                Kaitaia West    48    60
# 8     Statistical_Area_10  100900                   Rangitihi     3     6
# 9     Statistical_Area_11  101000              Oruru-Parapara     3     6
# 10    Statistical_Area_12  101100                 Taumarumaru    18    15
# 11    Statistical_Area_13  101200            Herekino-Takahue     3    12
# ...

# %%
objects=(df['description'][1:4])
y_pos = np.arange(len(objects))
performance = [] 
performance = df['2016'][1:4]

# %%
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Description')
plt.xlabel('2016')
plt.title('Movie')
 
plt.show()
